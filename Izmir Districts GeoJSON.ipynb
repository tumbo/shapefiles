# %%
import folium

# %%
map_izmir = folium.Map(location=[38.6140, 27.4296],zoom_start=9,max_zoom=12,min_zoom=9)

map_izmir.choropleth(geo_path='izmirDistricts.geo.json',fill_opacity=.25, fill_color='red',line_weight=2)
map_izmir
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;"></iframe></div></div>
